# %% [markdown]
# # Case Intro
# Term deposits are a major source of income for a bank. A term deposit is a cash investment held at a financial institution. Your money is invested for an agreed rate of interest over a fixed amount of time, or term. The bank has various outreach plans to sell term deposits to their customers such as email marketing, advertisements, telephonic marketing, and digital marketing.
#
# Telephonic marketing campaigns still remain one of the most effective way to reach out to people. However, they require huge investment as large call centers are hired to actually execute these campaigns. Hence, it is crucial to identify the customers most likely to convert beforehand so that they can be specifically targeted via call.
#
# The data is related to direct marketing campaigns (phone calls) of a Portuguese banking institution. The classification goal is to predict if the client will subscribe to a term deposit (variable y).
#
# Content
# The data is related to the direct marketing campaigns of a Portuguese banking institution. The marketing campaigns were based on phone calls. Often, more than one contact to the same client was required, in order to access if the product (bank term deposit) would be ('yes') or not ('no') subscribed by the customer or not. The data folder contains two datasets:-
#
# Bank.csv: 45,211 rows and 18 columns ordered by date (from May 2008 to November 2010)
#
# Detailed Column Descriptions
# bank client data:
#
# 1 - age (numeric)
#
# 2 - job : type of job (categorical: "admin.","unknown","unemployed","management","housemaid","entrepreneur","student",
# "blue-collar","self-employed","retired","technician","services")
#
# 3 - marital : marital status (categorical: "married","divorced","single"; note: "divorced" means divorced or widowed)
#
# 4 - education (categorical: "unknown","secondary","primary","tertiary")
#
# 5 - default: has credit in default? (binary: "yes","no")
#
# 6 - balance: average yearly balance, in euros (numeric)
#
# 7 - housing: has housing loan? (binary: "yes","no")
#
# 8 - loan: has personal loan? (binary: "yes","no")
# # related with the last contact of the current campaign:
# 9 - contact: contact communication type (categorical: "unknown","telephone","cellular")
# 10 - day: last contact day of the month (numeric)
#
# 11 - month: last contact month of year (categorical: "jan", "feb", "mar", …, "nov", "dec")
#
# 12 - duration: last contact duration, in seconds (numeric)
#
# # other attributes:
# 13 - campaign: number of contacts performed during this campaign and for this client (numeric, includes last contact)
#
# 14 - pdays: number of days that passed by after the client was last contacted from a previous campaign (numeric, -1 means client was not previously contacted)
#
# 15 - previous: number of contacts performed before this campaign and for this client (numeric)
#
# 16 - poutcome: outcome of the previous marketing campaign (categorical: "unknown","other","failure","success")
#
# Output variable (desired target):
#
# 17 - y - has the client subscribed a term deposit? (binary: "yes","no")
#
# Missing Attribute Values: None

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('https://raw.githubusercontent.com/ogut77/DataScience/main/data/Bank.csv',sep = ';')
df
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome    y
# 0        unknown    5   may       261         1     -1         0  unknown   no
# 1        unknown    5   may       151         1     -1         0  unknown   no
# 2        unknown    5   may        76         1     -1         0  unknown   no
# 3        unknown    5   may        92         1     -1         0  unknown   no
# 4        unknown    5   may       198         1     -1         0  unknown   no
# ...          ...  ...   ...       ...       ...    ...       ...      ...  ...
# 45206   cellular   17   nov       977         3     -1         0  unknown  yes
# 45207   cellular   17   nov       456         2     -1         0  unknown  yes
# 45208   cellular   17   nov      1127         5    184         3  success  yes
# 45209  telephone   17   nov       508         4     -1         0  unknown   no
# 45210   cellular   17   nov       361         2    188        11    other   no
#
# [45211 rows x 17 columns]

# %%
print(df.shape)
df.info()
df.isnull().sum()
# Out:
# (45211, 17)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  y          45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.9+ MB
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
#For object check the data 
for cn in df.columns:
  if(df[cn].dtype==object):
    print(df[cn].value_counts())
# Out:
# blue-collar      9732
# management       9458
# technician       7597
# admin.           5171
# services         4154
# retired          2264
# self-employed    1579
# entrepreneur     1487
# unemployed       1303
# housemaid        1240
# student           938
# unknown           288
# Name: job, dtype: int64
# married     27214
# single      12790
# divorced     5207
# Name: marital, dtype: int64
# secondary    23202
# tertiary     13301
# primary       6851
# unknown       1857
# Name: education, dtype: int64
# no     44396
# yes      815
# Name: default, dtype: int64
# yes    25130
# no     20081
# Name: housing, dtype: int64
# no     37967
# yes     7244
# Name: loan, dtype: int64
# cellular     29285
# unknown      13020
# telephone     2906
# Name: contact, dtype: int64
# may    13766
# jul     6895
# aug     6247
# jun     5341
# nov     3970
# apr     2932
# feb     2649
# jan     1403
# oct      738
# sep      579
# mar      477
# dec      214
# Name: month, dtype: int64
# unknown    36959
# failure     4901
# other       1840
# success     1511
# Name: poutcome, dtype: int64
# no     39922
# yes     5289
# Name: y, dtype: int64

# %%
def Encoder(df):
          from sklearn import preprocessing
          columnsToEncode = list(df.select_dtypes(include=['category','object']))
          le = preprocessing.LabelEncoder()
          for feature in columnsToEncode:
              try:
                  df[feature] = le.fit_transform(df[feature])
              except:
                  print('Error encoding '+feature)
          return df

# %%
df=Encoder(df)
df
# Out:
#        age  job  marital  education  default  balance  housing  loan  contact  \
# 0       58    4        1          2        0     2143        1     0        2
# 1       44    9        2          1        0       29        1     0        2
# 2       33    2        1          1        0        2        1     1        2
# 3       47    1        1          3        0     1506        1     0        2
# 4       33   11        2          3        0        1        0     0        2
# ...    ...  ...      ...        ...      ...      ...      ...   ...      ...
# 45206   51    9        1          2        0      825        0     0        0
# 45207   71    5        0          0        0     1729        0     0        0
# 45208   72    5        1          1        0     5715        0     0        0
# 45209   57    1        1          1        0      668        0     0        1
# 45210   37    2        1          1        0     2971        0     0        0
#
#        day  month  duration  campaign  pdays  previous  poutcome  y
# 0        5      8       261         1     -1         0         3  0
# 1        5      8       151         1     -1         0         3  0
# 2        5      8        76         1     -1         0         3  0
# 3        5      8        92         1     -1         0         3  0
# 4        5      8       198         1     -1         0         3  0
# ...    ...    ...       ...       ...    ...       ...       ... ..
# 45206   17      9       977         3     -1         0         3  1
# 45207   17      9       456         2     -1         0         3  1
# 45208   17      9      1127         5    184         3         2  1
# 45209   17      9       508         4     -1         0         3  0
# 45210   17      9       361         2    188        11         1  0
#
# [45211 rows x 17 columns]

# %%
y = df['y'] #Output
X = df.drop('y',axis=1)
X
# Out:
#        age  job  marital  education  default  balance  housing  loan  contact  \
# 0       58    4        1          2        0     2143        1     0        2
# 1       44    9        2          1        0       29        1     0        2
# 2       33    2        1          1        0        2        1     1        2
# 3       47    1        1          3        0     1506        1     0        2
# 4       33   11        2          3        0        1        0     0        2
# ...    ...  ...      ...        ...      ...      ...      ...   ...      ...
# 45206   51    9        1          2        0      825        0     0        0
# 45207   71    5        0          0        0     1729        0     0        0
# 45208   72    5        1          1        0     5715        0     0        0
# 45209   57    1        1          1        0      668        0     0        1
# 45210   37    2        1          1        0     2971        0     0        0
#
#        day  month  duration  campaign  pdays  previous  poutcome
# 0        5      8       261         1     -1         0         3
# 1        5      8       151         1     -1         0         3
# 2        5      8        76         1     -1         0         3
# 3        5      8        92         1     -1         0         3
# 4        5      8       198         1     -1         0         3
# ...    ...    ...       ...       ...    ...       ...       ...
# 45206   17      9       977         3     -1         0         3
# 45207   17      9       456         2     -1         0         3
# 45208   17      9      1127         5    184         3         2
# 45209   17      9       508         4     -1         0         3
# 45210   17      9       361         2    188        11         1
#
# [45211 rows x 16 columns]

# %%
from sklearn.model_selection import  train_test_split


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=17)

# %% [markdown]
#
#
#
# Q1)Using  Random Forest,XGBoost, Light GBM and Gradient Boosting Classifier with default parameters (no parameter specifications except random_state) calculate Accuracy on Test data. Which method gives the best accuracy on test data

# %% [markdown]
# Q2) Using optuna hyperparmeter optimization technique and 100 trial
#
#  a)find best methods with  parameters  using Cross validation (CV=3) technique for the range of   parameters below. What are the best parameters for the method with highest cross validation accuracy?
#
# "max_depth": range(2, 16), "max_features": range(2, 16)
#
#  b)Evaluate the performance of the  method with highest cross validation accuracy on test data.What is the accuracy value?

# %%
#Question 1
#Random Forest 
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
forest = RandomForestClassifier(random_state=17 )
forest.fit(X_train, y_train)

# make predictions for test data

forest_pred = forest.predict(X_test)
print(accuracy_score(y_test, forest_pred) )
# Out:
# 0.9025037600636999

# %%
#Light GBM
import lightgbm as lgb
lgb_model = lgb.LGBMClassifier(random_state=17)
lgb_model.fit(X_train, y_train)
# make predictions for test data
print(accuracy_score(y_test, lgb_model.predict(X_test)))
# Out:
# 0.9044501459789437

# %%
# XGBoost
from xgboost import XGBClassifier
model = XGBClassifier(random_state=17)
model.fit(X_train, y_train)
# make predictions for test data
xgb_pred = model.predict(X_test)
print(accuracy_score(y_test, xgb_pred))
# Out:
# 0.90020348580023

# %%
#Gradient Boosting
from sklearn.ensemble import GradientBoostingClassifier
gbm_model = GradientBoostingClassifier(random_state=17)
gbm_model.fit(X_train, y_train)
print(accuracy_score(y_test, gbm_model.predict(X_test)))
# Out:
# 0.9018844554543042

# %% [markdown]
# In my opinion, Light GBM gives the best accuracy on test data with slight difference from others.

# %%
#Question 2
# !pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-2.10.0-py3-none-any.whl (308 kB)
#      |████████████████████████████████| 308 kB 5.1 MB/s
# Collecting cmaes>=0.8.2
#   Downloading cmaes-0.8.2-py3-none-any.whl (15 kB)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from optuna) (3.13)
# Collecting alembic
#   Downloading alembic-1.7.7-py3-none-any.whl (210 kB)
#      |████████████████████████████████| 210 kB 50.7 MB/s
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from optuna) (21.3)
# Collecting cliff
#   Downloading cliff-3.10.1-py3-none-any.whl (81 kB)
#      |████████████████████████████████| 81 kB 8.1 MB/s
# Collecting colorlog
#   Downloading colorlog-6.6.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: scipy!=1.4.0 in /usr/local/lib/python3.7/dist-packages (from optuna) (1.4.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from optuna) (4.63.0)
# Requirement already satisfied: sqlalchemy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from optuna) (1.4.32)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from optuna) (1.21.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->optuna) (3.0.7)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from sqlalchemy>=1.1.0->optuna) (4.11.3)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.7/dist-packages (from sqlalchemy>=1.1.0->optuna) (1.1.2)
# Collecting Mako
#   Downloading Mako-1.2.0-py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 6.0 MB/s
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from alembic->optuna) (5.4.0)
# Collecting pbr!=2.1.0,>=2.0.0
#   Downloading pbr-5.8.1-py2.py3-none-any.whl (113 kB)
#      |████████████████████████████████| 113 kB 56.0 MB/s
# Collecting cmd2>=1.0.0
#   Downloading cmd2-2.4.0-py3-none-any.whl (150 kB)
#      |████████████████████████████████| 150 kB 37.5 MB/s
# Requirement already satisfied: PrettyTable>=0.7.2 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna) (3.2.0)
# Collecting stevedore>=2.0.1
#   Downloading stevedore-3.5.0-py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 4.9 MB/s
# Collecting autopage>=0.4.0
#   Downloading autopage-0.5.0-py3-none-any.whl (29 kB)
# Requirement already satisfied: attrs>=16.3.0 in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna) (21.4.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna) (3.10.0.2)
# Collecting pyperclip>=1.6
#   Downloading pyperclip-1.8.2.tar.gz (20 kB)
# Requirement already satisfied: wcwidth>=0.1.7 in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna) (0.2.5)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->sqlalchemy>=1.1.0->optuna) (3.7.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.7/dist-packages (from Mako->alembic->optuna) (2.0.1)
# Building wheels for collected packages: pyperclip
#   Building wheel for pyperclip (setup.py) ... done
#   Created wheel for pyperclip: filename=pyperclip-1.8.2-py3-none-any.whl size=11137 sha256=36fcb90347d5252b0b4546b59a80bb748094a1c416730149017f9b7c75160a8c
#   Stored in directory: /root/.cache/pip/wheels/9f/18/84/8f69f8b08169c7bae2dde6bd7daf0c19fca8c8e500ee620a28
# Successfully built pyperclip
# Installing collected packages: pyperclip, pbr, stevedore, Mako, cmd2, autopage, colorlog, cmaes, cliff, alembic, optuna
# Successfully installed Mako-1.2.0 alembic-1.7.7 autopage-0.5.0 cliff-3.10.1 cmaes-0.8.2 cmd2-2.4.0 colorlog-6.6.0 optuna-2.10.0 pbr-5.8.1 pyperclip-1.8.2 stevedore-3.5.0

# %%
import optuna

import sklearn.datasets
import sklearn.ensemble
import sklearn.model_selection
import sklearn.svm

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=17)
# FYI: Objective functions can take additional arguments
# (https://optuna.readthedocs.io/en/stable/faq.html#objective-func-additional-args).
def objective(trial):
    x, y = X_train,y_train

    regressor_name = trial.suggest_categorical("regressor", ["GradientBoosting", "XGBoost","LightGBM","RandomForest"])
    if regressor_name == "GradientBoosting":
         max_depth = trial.suggest_int("max_depth",2,16)
         max_features = trial.suggest_int("max_features",2,16)
         regressor_obj = sklearn.ensemble.GradientBoostingRegressor(random_state=17,  max_depth=max_depth, max_features=max_features )
    
    elif regressor_name == "XGBoost":
         from xgboost import XGBRegressor
         max_depth = trial.suggest_int("max_depth",2,16)
         max_features = trial.suggest_int("max_features",2,16)
         regressor_obj = XGBRegressor(random_state=17,  max_depth=max_depth, max_features=max_features )
        
         

    elif regressor_name == "LightGBM":
         import lightgbm as lgb
         max_depth = trial.suggest_int("max_depth",2,16)
         max_features = trial.suggest_int("max_features",2,16)
         regressor_obj = lgb.LGBMRegressor(random_state=17,  max_depth=max_depth, max_features=max_features )
        
       
   
    else:
         max_depth = trial.suggest_int("max_depth",2,16)
         max_features = trial.suggest_int("max_features",2,16)
         regressor_obj = sklearn.ensemble.RandomForestRegressor(random_state=17,  max_depth=max_depth, max_features=max_features )

     

    r2=sklearn.model_selection.cross_val_score(regressor_obj, x, y, n_jobs=-1, cv=3).mean()
    
    return r2


if __name__ == "__main__":
    study = optuna.create_study(direction="maximize")
    study.optimize(objective, n_trials=100)
    print(study.best_trial)
# Out:
# [I 2022-03-27 20:39:43,105] A new study created in memory with name: no-name-3248443d-3099-4427-874c-761cbd6b293b
# [I 2022-03-27 20:39:46,096] Trial 0 finished with value: 0.38680737289053396 and parameters: {'regressor': 'LightGBM', 'max_depth': 14, 'max_features': 16}. Best is trial 0 with value: 0.38680737289053396.
# [I 2022-03-27 20:39:50,328] Trial 1 finished with value: 0.34117778179498953 and parameters: {'regressor': 'RandomForest', 'max_depth': 10, 'max_features': 3}. Best is trial 0 with value: 0.38680737289053396.
# [I 2022-03-27 20:39:54,094] Trial 2 finished with value: 0.3561540023481789 and parameters: {'regressor': 'XGBoost', 'max_depth': 3, 'max_features': 11}. Best is trial 0 with value: 0.38680737289053396.
# [I 2022-03-27 20:40:08,767] Trial 3 finished with value: 0.3613131613634848 and parameters: {'regressor': 'RandomForest', 'max_depth': 15, 'max_features': 11}. Best is trial 0 with value: 0.38680737289053396.
# [I 2022-03-27 20:40:19,125] Trial 4 finished with value: 0.36327048590192845 and parameters: {'regressor': 'XGBoost', 'max_depth': 8, 'max_features': 2}. Best is trial 0 with value: 0.38680737289053396.
# [I 2022-03-27 20:40:21,940] Trial 5 finished with value: 0.32754799653604666 and parameters: {'regressor': 'XGBoost', 'max_depth': 2, 'max_features': 3}. Best is trial 0 with value: 0.38680737289053396.
# [I 2022-03-27 20:40:50,570] Trial 6 finished with value: 0.300799661733262 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 15, 'max_features': 12}. Best is trial 0 with value: 0.38680737289053396.
# [I 2022-03-27 20:40:55,982] Trial 7 finished with value: 0.35526912049821197 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 3, 'max_features': 11}. Best is trial 0 with value: 0.38680737289053396.
# [I 2022-03-27 20:40:57,044] Trial 8 finished with value: 0.3837451601243402 and parameters: {'regressor': 'LightGBM', 'max_depth': 6, 'max_features': 8}. Best is trial 0 with value: 0.38680737289053396.
# [I 2022-03-27 20:40:59,857] Trial 9 finished with value: 0.32754799653604666 and parameters: {'regressor': 'XGBoost', 'max_depth': 2, 'max_features': 11}. Best is trial 0 with value: 0.38680737289053396.
# [I 2022-03-27 20:41:01,054] Trial 10 finished with value: 0.3882812159412718 and parameters: {'regressor': 'LightGBM', 'max_depth': 12, 'max_features': 16}. Best is trial 10 with value: 0.3882812159412718.
# [I 2022-03-27 20:41:02,210] Trial 11 finished with value: 0.3882812159412718 and parameters: {'regressor': 'LightGBM', 'max_depth': 12, 'max_features': 16}. Best is trial 10 with value: 0.3882812159412718.
# [I 2022-03-27 20:41:03,364] Trial 12 finished with value: 0.38886466722079166 and parameters: {'regressor': 'LightGBM', 'max_depth': 11, 'max_features': 16}. Best is trial 12 with value: 0.38886466722079166.
# [I 2022-03-27 20:41:04,536] Trial 13 finished with value: 0.38886466722079166 and parameters: {'regressor': 'LightGBM', 'max_depth': 11, 'max_features': 14}. Best is trial 12 with value: 0.38886466722079166.
# [I 2022-03-27 20:41:05,724] Trial 14 finished with value: 0.3892534050390631 and parameters: {'regressor': 'LightGBM', 'max_depth': 10, 'max_features': 13}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:41:06,929] Trial 15 finished with value: 0.38780396438906567 and parameters: {'regressor': 'LightGBM', 'max_depth': 8, 'max_features': 8}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:41:08,126] Trial 16 finished with value: 0.3837451601243402 and parameters: {'regressor': 'LightGBM', 'max_depth': 6, 'max_features': 14}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:41:09,310] Trial 17 finished with value: 0.38634580523343964 and parameters: {'regressor': 'LightGBM', 'max_depth': 13, 'max_features': 13}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:41:22,178] Trial 18 finished with value: 0.348097286333011 and parameters: {'regressor': 'RandomForest', 'max_depth': 9, 'max_features': 14}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:41:28,272] Trial 19 finished with value: 0.3798527675373721 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 7, 'max_features': 5}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:41:29,450] Trial 20 finished with value: 0.3892534050390631 and parameters: {'regressor': 'LightGBM', 'max_depth': 10, 'max_features': 9}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:41:30,622] Trial 21 finished with value: 0.3892534050390631 and parameters: {'regressor': 'LightGBM', 'max_depth': 10, 'max_features': 7}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:41:31,796] Trial 22 finished with value: 0.3892534050390631 and parameters: {'regressor': 'LightGBM', 'max_depth': 10, 'max_features': 6}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:41:32,988] Trial 23 finished with value: 0.3858121530268348 and parameters: {'regressor': 'LightGBM', 'max_depth': 9, 'max_features': 6}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:41:34,167] Trial 24 finished with value: 0.38886466722079166 and parameters: {'regressor': 'LightGBM', 'max_depth': 11, 'max_features': 9}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:41:35,326] Trial 25 finished with value: 0.38634580523343964 and parameters: {'regressor': 'LightGBM', 'max_depth': 13, 'max_features': 6}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:41:36,420] Trial 26 finished with value: 0.38119356678276883 and parameters: {'regressor': 'LightGBM', 'max_depth': 5, 'max_features': 7}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:41:42,325] Trial 27 finished with value: 0.3572189908513801 and parameters: {'regressor': 'RandomForest', 'max_depth': 10, 'max_features': 5}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:41:53,800] Trial 28 finished with value: 0.36870060084459966 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 8, 'max_features': 9}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:41:54,967] Trial 29 finished with value: 0.38662046933653405 and parameters: {'regressor': 'LightGBM', 'max_depth': 16, 'max_features': 5}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:41:56,134] Trial 30 finished with value: 0.38634580523343964 and parameters: {'regressor': 'LightGBM', 'max_depth': 13, 'max_features': 7}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:41:57,296] Trial 31 finished with value: 0.3892534050390631 and parameters: {'regressor': 'LightGBM', 'max_depth': 10, 'max_features': 10}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:41:58,468] Trial 32 finished with value: 0.3892534050390631 and parameters: {'regressor': 'LightGBM', 'max_depth': 10, 'max_features': 9}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:41:59,667] Trial 33 finished with value: 0.3858121530268348 and parameters: {'regressor': 'LightGBM', 'max_depth': 9, 'max_features': 8}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:42:11,683] Trial 34 finished with value: 0.3597334742626837 and parameters: {'regressor': 'RandomForest', 'max_depth': 12, 'max_features': 10}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:42:12,858] Trial 35 finished with value: 0.38886466722079166 and parameters: {'regressor': 'LightGBM', 'max_depth': 11, 'max_features': 10}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:42:21,605] Trial 36 finished with value: 0.3722141260506455 and parameters: {'regressor': 'XGBoost', 'max_depth': 7, 'max_features': 4}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:42:22,790] Trial 37 finished with value: 0.38780396438906567 and parameters: {'regressor': 'LightGBM', 'max_depth': 8, 'max_features': 9}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:42:37,915] Trial 38 finished with value: 0.34157984387705786 and parameters: {'regressor': 'XGBoost', 'max_depth': 10, 'max_features': 7}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:42:50,942] Trial 39 finished with value: 0.36150889069189546 and parameters: {'regressor': 'RandomForest', 'max_depth': 14, 'max_features': 10}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:43:09,770] Trial 40 finished with value: 0.3411443951715967 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 10, 'max_features': 12}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:43:10,975] Trial 41 finished with value: 0.3858121530268348 and parameters: {'regressor': 'LightGBM', 'max_depth': 9, 'max_features': 8}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:43:12,157] Trial 42 finished with value: 0.3892534050390631 and parameters: {'regressor': 'LightGBM', 'max_depth': 10, 'max_features': 6}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:43:13,368] Trial 43 finished with value: 0.3882812159412718 and parameters: {'regressor': 'LightGBM', 'max_depth': 12, 'max_features': 10}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:43:14,562] Trial 44 finished with value: 0.38886466722079166 and parameters: {'regressor': 'LightGBM', 'max_depth': 11, 'max_features': 6}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:43:15,774] Trial 45 finished with value: 0.3858121530268348 and parameters: {'regressor': 'LightGBM', 'max_depth': 9, 'max_features': 4}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:43:24,574] Trial 46 finished with value: 0.3722141260506455 and parameters: {'regressor': 'XGBoost', 'max_depth': 7, 'max_features': 12}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:43:25,758] Trial 47 finished with value: 0.3882812159412718 and parameters: {'regressor': 'LightGBM', 'max_depth': 12, 'max_features': 8}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:43:26,948] Trial 48 finished with value: 0.38780396438906567 and parameters: {'regressor': 'LightGBM', 'max_depth': 8, 'max_features': 2}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:43:28,125] Trial 49 finished with value: 0.38886466722079166 and parameters: {'regressor': 'LightGBM', 'max_depth': 11, 'max_features': 3}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:43:39,627] Trial 50 finished with value: 0.3546233847353573 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 10, 'max_features': 7}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:43:40,828] Trial 51 finished with value: 0.3858121530268348 and parameters: {'regressor': 'LightGBM', 'max_depth': 9, 'max_features': 15}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:43:42,014] Trial 52 finished with value: 0.3892534050390631 and parameters: {'regressor': 'LightGBM', 'max_depth': 10, 'max_features': 11}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:43:43,194] Trial 53 finished with value: 0.38886466722079166 and parameters: {'regressor': 'LightGBM', 'max_depth': 11, 'max_features': 11}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:43:44,370] Trial 54 finished with value: 0.3892534050390631 and parameters: {'regressor': 'LightGBM', 'max_depth': 10, 'max_features': 13}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:43:45,557] Trial 55 finished with value: 0.3858121530268348 and parameters: {'regressor': 'LightGBM', 'max_depth': 9, 'max_features': 13}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:43:46,730] Trial 56 finished with value: 0.38634580523343964 and parameters: {'regressor': 'LightGBM', 'max_depth': 13, 'max_features': 6}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:43:47,939] Trial 57 finished with value: 0.3892534050390631 and parameters: {'regressor': 'LightGBM', 'max_depth': 10, 'max_features': 12}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:43:49,117] Trial 58 finished with value: 0.3882812159412718 and parameters: {'regressor': 'LightGBM', 'max_depth': 12, 'max_features': 12}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:44:01,255] Trial 59 finished with value: 0.35834194178732703 and parameters: {'regressor': 'RandomForest', 'max_depth': 11, 'max_features': 11}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:44:10,045] Trial 60 finished with value: 0.3722141260506455 and parameters: {'regressor': 'XGBoost', 'max_depth': 7, 'max_features': 13}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:44:11,248] Trial 61 finished with value: 0.3892534050390631 and parameters: {'regressor': 'LightGBM', 'max_depth': 10, 'max_features': 9}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:44:12,439] Trial 62 finished with value: 0.38780396438906567 and parameters: {'regressor': 'LightGBM', 'max_depth': 8, 'max_features': 9}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:44:13,638] Trial 63 finished with value: 0.3892534050390631 and parameters: {'regressor': 'LightGBM', 'max_depth': 10, 'max_features': 12}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:44:14,811] Trial 64 finished with value: 0.3858121530268348 and parameters: {'regressor': 'LightGBM', 'max_depth': 9, 'max_features': 10}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:44:15,999] Trial 65 finished with value: 0.38886466722079166 and parameters: {'regressor': 'LightGBM', 'max_depth': 11, 'max_features': 7}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:44:17,192] Trial 66 finished with value: 0.38780396438906567 and parameters: {'regressor': 'LightGBM', 'max_depth': 8, 'max_features': 5}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:44:26,168] Trial 67 finished with value: 0.36804181389396806 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 9, 'max_features': 6}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:44:27,321] Trial 68 finished with value: 0.3892534050390631 and parameters: {'regressor': 'LightGBM', 'max_depth': 10, 'max_features': 8}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:44:28,517] Trial 69 finished with value: 0.3882812159412718 and parameters: {'regressor': 'LightGBM', 'max_depth': 12, 'max_features': 8}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:44:29,674] Trial 70 finished with value: 0.38886466722079166 and parameters: {'regressor': 'LightGBM', 'max_depth': 11, 'max_features': 15}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:44:30,853] Trial 71 finished with value: 0.3892534050390631 and parameters: {'regressor': 'LightGBM', 'max_depth': 10, 'max_features': 12}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:44:32,034] Trial 72 finished with value: 0.3892534050390631 and parameters: {'regressor': 'LightGBM', 'max_depth': 10, 'max_features': 11}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:44:33,213] Trial 73 finished with value: 0.38886466722079166 and parameters: {'regressor': 'LightGBM', 'max_depth': 11, 'max_features': 11}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:44:34,411] Trial 74 finished with value: 0.3858121530268348 and parameters: {'regressor': 'LightGBM', 'max_depth': 9, 'max_features': 11}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:44:47,532] Trial 75 finished with value: 0.35398758463301433 and parameters: {'regressor': 'RandomForest', 'max_depth': 10, 'max_features': 13}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:44:48,707] Trial 76 finished with value: 0.38886466722079166 and parameters: {'regressor': 'LightGBM', 'max_depth': 11, 'max_features': 14}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:44:49,912] Trial 77 finished with value: 0.3858121530268348 and parameters: {'regressor': 'LightGBM', 'max_depth': 9, 'max_features': 10}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:44:51,091] Trial 78 finished with value: 0.3892534050390631 and parameters: {'regressor': 'LightGBM', 'max_depth': 10, 'max_features': 9}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:44:51,928] Trial 79 finished with value: 0.359339894831263 and parameters: {'regressor': 'LightGBM', 'max_depth': 3, 'max_features': 10}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:45:06,197] Trial 80 finished with value: 0.34157984387705786 and parameters: {'regressor': 'XGBoost', 'max_depth': 10, 'max_features': 7}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:45:07,400] Trial 81 finished with value: 0.3858121530268348 and parameters: {'regressor': 'LightGBM', 'max_depth': 9, 'max_features': 14}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:45:08,589] Trial 82 finished with value: 0.3892534050390631 and parameters: {'regressor': 'LightGBM', 'max_depth': 10, 'max_features': 8}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:45:09,785] Trial 83 finished with value: 0.3892534050390631 and parameters: {'regressor': 'LightGBM', 'max_depth': 10, 'max_features': 8}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:45:10,862] Trial 84 finished with value: 0.38886466722079166 and parameters: {'regressor': 'LightGBM', 'max_depth': 11, 'max_features': 9}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:45:23,025] Trial 85 finished with value: 0.3451785741393776 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 12, 'max_features': 6}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:45:24,199] Trial 86 finished with value: 0.3892534050390631 and parameters: {'regressor': 'LightGBM', 'max_depth': 10, 'max_features': 5}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:45:25,392] Trial 87 finished with value: 0.38780396438906567 and parameters: {'regressor': 'LightGBM', 'max_depth': 8, 'max_features': 4}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:45:26,581] Trial 88 finished with value: 0.3858121530268348 and parameters: {'regressor': 'LightGBM', 'max_depth': 9, 'max_features': 12}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:45:27,762] Trial 89 finished with value: 0.38886466722079166 and parameters: {'regressor': 'LightGBM', 'max_depth': 11, 'max_features': 13}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:45:28,962] Trial 90 finished with value: 0.3858121530268348 and parameters: {'regressor': 'LightGBM', 'max_depth': 9, 'max_features': 12}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:45:30,146] Trial 91 finished with value: 0.3892534050390631 and parameters: {'regressor': 'LightGBM', 'max_depth': 10, 'max_features': 9}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:45:31,341] Trial 92 finished with value: 0.3892534050390631 and parameters: {'regressor': 'LightGBM', 'max_depth': 10, 'max_features': 9}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:45:32,521] Trial 93 finished with value: 0.3892534050390631 and parameters: {'regressor': 'LightGBM', 'max_depth': 10, 'max_features': 11}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:45:33,698] Trial 94 finished with value: 0.3892534050390631 and parameters: {'regressor': 'LightGBM', 'max_depth': 10, 'max_features': 10}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:45:45,848] Trial 95 finished with value: 0.35834194178732703 and parameters: {'regressor': 'RandomForest', 'max_depth': 11, 'max_features': 11}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:45:47,024] Trial 96 finished with value: 0.3858121530268348 and parameters: {'regressor': 'LightGBM', 'max_depth': 9, 'max_features': 12}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:45:47,970] Trial 97 finished with value: 0.3730531377754717 and parameters: {'regressor': 'LightGBM', 'max_depth': 4, 'max_features': 8}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:46:03,882] Trial 98 finished with value: 0.3297498389624873 and parameters: {'regressor': 'XGBoost', 'max_depth': 11, 'max_features': 7}. Best is trial 14 with value: 0.3892534050390631.
# [I 2022-03-27 20:46:05,062] Trial 99 finished with value: 0.3882812159412718 and parameters: {'regressor': 'LightGBM', 'max_depth': 12, 'max_features': 9}. Best is trial 14 with value: 0.3892534050390631.
# FrozenTrial(number=14, values=[0.3892534050390631], datetime_start=datetime.datetime(2022, 3, 27, 20, 41, 4, 538245), datetime_complete=datetime.datetime(2022, 3, 27, 20, 41, 5, 724448), params={'regressor': 'LightGBM', 'max_depth': 10, 'max_features': 13}, distributions={'regressor': CategoricalDistribution(choices=('GradientBoosting', 'XGBoost', 'LightGBM', 'RandomForest')), 'max_depth': IntUniformDistribution(high=16, low=2, step=1), 'max_features': IntUniformDistribution(high=16, low=2, step=1)}, user_attrs={}, system_attrs={}, intermediate_values={}, trial_id=14, state=TrialState.COMPLETE, value=None)

# %%
print(study.best_params)
# Out:
# {'regressor': 'LightGBM', 'max_depth': 10, 'max_features': 13}

# %%
import lightgbm as lgb
lgb_model = lgb.LGBMClassifier(random_state=17,max_depth=10,max_features=11)
lgb_model.fit(X_train, y_train)
# make predictions for test data
print(accuracy_score(y_test, lgb_model.predict(X_test)))
# Out:
# 0.905511811023622

# %% [markdown]
# For Q3 and Q4 ,use the following data.

# %%
dr=pd.read_csv('https://raw.githubusercontent.com/ogut77/DataScience/main/data/diamond.csv')
dr
# Out:
#       Carat Weight              Cut Color Clarity Polish Symmetry Report  \
# 0             1.10            Ideal     H     SI1     VG       EX    GIA
# 1             0.83            Ideal     H     VS1     ID       ID   AGSL
# 2             0.85            Ideal     H     SI1     EX       EX    GIA
# 3             0.91            Ideal     E     SI1     VG       VG    GIA
# 4             0.83            Ideal     G     SI1     EX       EX    GIA
# ...            ...              ...   ...     ...    ...      ...    ...
# 5995          1.03            Ideal     D     SI1     EX       EX    GIA
# 5996          1.00        Very Good     D     SI1     VG       VG    GIA
# 5997          1.02            Ideal     D     SI1     EX       EX    GIA
# 5998          1.27  Signature-Ideal     G     VS1     EX       EX    GIA
# 5999          2.19            Ideal     E     VS1     EX       EX    GIA
#
#       Price
# 0      5169
# 1      3470
# 2      3183
# 3      4370
# 4      3171
# ...     ...
# 5995   6250
# 5996   5328
# 5997   6157
# 5998  11206
# 5999  30507
#
# [6000 rows x 8 columns]

# %%
def Encoder(df):
          from sklearn import preprocessing
          columnsToEncode = list(df.select_dtypes(include=['category','object']))
          le = preprocessing.LabelEncoder()
          for feature in columnsToEncode:
              try:
                  df[feature] = le.fit_transform(df[feature])
              except:
                  print('Error encoding '+feature)
          return df

# %%
dr=Encoder(dr)
dr
# Out:
#       Carat Weight  Cut  Color  Clarity  Polish  Symmetry  Report  Price
# 0             1.10    2      4        2       3         0       1   5169
# 1             0.83    2      4        3       2         2       0   3470
# 2             0.85    2      4        2       0         0       1   3183
# 3             0.91    2      1        2       3         3       1   4370
# 4             0.83    2      3        2       0         0       1   3171
# ...            ...  ...    ...      ...     ...       ...     ...    ...
# 5995          1.03    2      0        2       0         0       1   6250
# 5996          1.00    4      0        2       3         3       1   5328
# 5997          1.02    2      0        2       0         0       1   6157
# 5998          1.27    3      3        3       0         0       1  11206
# 5999          2.19    2      1        3       0         0       1  30507
#
# [6000 rows x 8 columns]

# %%
y = dr['Price'] #Output
X = dr.drop('Price',axis=1)
X
# Out:
#       Carat Weight  Cut  Color  Clarity  Polish  Symmetry  Report
# 0             1.10    2      4        2       3         0       1
# 1             0.83    2      4        3       2         2       0
# 2             0.85    2      4        2       0         0       1
# 3             0.91    2      1        2       3         3       1
# 4             0.83    2      3        2       0         0       1
# ...            ...  ...    ...      ...     ...       ...     ...
# 5995          1.03    2      0        2       0         0       1
# 5996          1.00    4      0        2       3         3       1
# 5997          1.02    2      0        2       0         0       1
# 5998          1.27    3      3        3       0         0       1
# 5999          2.19    2      1        3       0         0       1
#
# [6000 rows x 7 columns]

# %%
from sklearn.model_selection import  train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=17)

# %% [markdown]
# Q3)Using Linear Regression,Decison Tree Random Forest,XGBoost, Light GBM and Gradient Boosting Classifier with default parameters (no parameter specifications except random_state) calculate R2 statistics on test data. Which method gives the best accuracy on test data

# %% [markdown]
# Q4) Using optuna hyperparmeter optimization technique (100 trial)  with Random Forest,XGBoost, Light GBM and Gradient Boosting Regressor
#
# a)find best methods with  parameters  using Cross validation (CV=3) technique for the range of   parameters below. What are the best parameters for the method with highest cross validation R2?
#
# "max_depth": range(2, 7), "max_features": range(2, 7)
#
#  b)Evaluate the performance of the  method with highest cross validation R2 on test data. What is the R2 value?

# %%
#Question 3
def evalmetric(y,ypred):
 import numpy as np
 e = y - ypred 
 mse_f = np.mean(e**2)
 rmse_f = np.sqrt(mse_f)
 mae_f = np.mean(abs(e))
 mape_f = 100*np.mean(abs(e/y))
 r2_f = 1-(sum(e**2)/sum((y-np.mean(y))**2))
 print("MSE:", mse_f)
 print("RMSE:", rmse_f)
 print("MAE:",mae_f)
 print("MAPE:",mape_f)
 print("R-Squared:", r2_f)

# %%
from sklearn.tree import DecisionTreeRegressor
dtr = DecisionTreeRegressor(random_state=17)
dtr.fit(X_train,y_train)
print('Test Data')
y_pred2 = dtr.predict(X_test)
evalmetric(y_test,y_pred2)
# Out:
# Test Data
# MSE: 4222331.073863685
# RMSE: 2054.83115458757
# MAE: 1016.694373015873
# MAPE: 7.833274374700561
# R-Squared: 0.9592329752745201

# %%
from sklearn.ensemble import RandomForestRegressor
rfr = RandomForestRegressor(random_state=17)
rfr.fit(X_train,y_train)
print('Test Data')
y_pred2 = rfr.predict(X_test)
evalmetric(y_test,y_pred2)
# Out:
# Test Data
# MSE: 2074962.900565573
# RMSE: 1440.4731516295515
# MAE: 778.3143303628775
# MAPE: 6.220426902140035
# R-Squared: 0.9799660276771226

# %%
from sklearn.ensemble import GradientBoostingRegressor
from time import time

gbr = GradientBoostingRegressor(random_state=17)
gbr.fit(X_train, y_train)
print('Test Data')
y_pred2 = gbr.predict(X_test)
evalmetric(y_test,y_pred2)
# Out:
# Test Data
# MSE: 2702865.535065862
# RMSE: 1644.0393958375396
# MAE: 878.4993508475277
# MAPE: 7.394144503096002
# R-Squared: 0.9739035655494326

# %%
from xgboost import XGBRegressor
xgr = XGBRegressor(random_state=17)
xgr.fit(X_train, y_train)
print('Test Data')
y_pred2 = xgr.predict(X_test)
evalmetric(y_test,y_pred2)
# Out:
# [20:53:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Test Data
# MSE: 2822838.991584785
# RMSE: 1680.1306471774108
# MAE: 881.3905965169271
# MAPE: 7.3386749783130245
# R-Squared: 0.9727452099437854

# %%
from time import time
import lightgbm as lgb
t0 = time()
lgr = lgb.LGBMRegressor(random_state=17)
lgr.fit(X_train, y_train)
print('Test Data')
y_pred2 = lgr.predict(X_test)
evalmetric(y_test,y_pred2)
# Out:
# Test Data
# MSE: 1940840.8294753155
# RMSE: 1393.1406352107153
# MAE: 701.0864858904304
# MAPE: 5.433753614630323
# R-Squared: 0.9812609895578275

# %%
import sklearn.linear_model as skl_lm
regr = skl_lm.LinearRegression()
regr.fit(X_train,y_train)
print('Test Data')
y_pred2 = regr.predict(X_test)
evalmetric(y_test,y_pred2)
# Out:
# Test Data
# MSE: 18292450.049325157
# RMSE: 4276.967389322153
# MAE: 2701.997276609754
# MAPE: 30.68442425409791
# R-Squared: 0.8233845829696962

# %% [markdown]
# #Question 4
# a) "max_depth": range(2, 7), "max_features": range(2, 7)

# %%
import optuna

import sklearn.datasets
import sklearn.ensemble
import sklearn.model_selection
import sklearn.svm


def objective(trial):
    x, y = X_train,y_train

    regressor_name = trial.suggest_categorical("regressor", ["GradientBoosting", "XGBoost","LightGBM","RandomForest"])
    if regressor_name == "GradientBoosting":
         max_depth = trial.suggest_int("max_depth", 2,7)
         max_features = trial.suggest_int("max_features", 2,7)
         regressor_obj = sklearn.ensemble.GradientBoostingRegressor(random_state=17,  max_depth=max_depth, max_features=max_features )
    
    elif regressor_name == "XGBoost":
         from xgboost import XGBRegressor
         max_depth = trial.suggest_int("max_depth", 2,7)
         max_features = trial.suggest_int("max_features", 2,7)
         regressor_obj = XGBRegressor(random_state=17,  max_depth=max_depth, max_features=max_features )
        
         

    elif regressor_name == "LightGBM":
         import lightgbm as lgb
         max_depth = trial.suggest_int("max_depth", 2,7)
         max_features = trial.suggest_int("max_features", 2,7)
         regressor_obj = lgb.LGBMRegressor(random_state=17,  max_depth=max_depth, max_features=max_features )
        
       
   
    else:
         max_depth = trial.suggest_int("max_depth", 2,7)
         max_features = trial.suggest_int("max_features", 2,7)
         regressor_obj = sklearn.ensemble.RandomForestRegressor(random_state=17,  max_depth=max_depth, max_features=max_features )

     

    r2=sklearn.model_selection.cross_val_score(regressor_obj, x, y, n_jobs=-1, cv=3).mean()
   
    return r2


if __name__ == "__main__":
    study = optuna.create_study(direction="maximize")
    study.optimize(objective, n_trials=100)
    print(study.best_trial)
# Out:
# [I 2022-03-27 21:04:43,195] A new study created in memory with name: no-name-0ceb05f2-96a8-4b83-a7b9-830358df4d72
# [I 2022-03-27 21:04:46,286] Trial 0 finished with value: 0.9533571582401862 and parameters: {'regressor': 'RandomForest', 'max_depth': 7, 'max_features': 3}. Best is trial 0 with value: 0.9533571582401862.
# [I 2022-03-27 21:04:47,158] Trial 1 finished with value: 0.9844596675452194 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 6, 'max_features': 7}. Best is trial 1 with value: 0.9844596675452194.
# [I 2022-03-27 21:04:47,500] Trial 2 finished with value: 0.9706874365810324 and parameters: {'regressor': 'LightGBM', 'max_depth': 3, 'max_features': 2}. Best is trial 1 with value: 0.9844596675452194.
# [I 2022-03-27 21:04:47,626] Trial 3 finished with value: 0.9706874365810324 and parameters: {'regressor': 'LightGBM', 'max_depth': 3, 'max_features': 5}. Best is trial 1 with value: 0.9844596675452194.
# [I 2022-03-27 21:04:48,209] Trial 4 finished with value: 0.9842502916631269 and parameters: {'regressor': 'XGBoost', 'max_depth': 5, 'max_features': 3}. Best is trial 1 with value: 0.9844596675452194.
# [I 2022-03-27 21:04:48,576] Trial 5 finished with value: 0.9771377197784242 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 5, 'max_features': 2}. Best is trial 1 with value: 0.9844596675452194.
# [I 2022-03-27 21:04:49,224] Trial 6 finished with value: 0.9845567951821383 and parameters: {'regressor': 'XGBoost', 'max_depth': 6, 'max_features': 3}. Best is trial 6 with value: 0.9845567951821383.
# [I 2022-03-27 21:04:49,439] Trial 7 finished with value: 0.9758296442252078 and parameters: {'regressor': 'LightGBM', 'max_depth': 7, 'max_features': 4}. Best is trial 6 with value: 0.9845567951821383.
# [I 2022-03-27 21:04:49,932] Trial 8 finished with value: 0.9852245763533835 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 4, 'max_features': 5}. Best is trial 8 with value: 0.9852245763533835.
# [I 2022-03-27 21:04:50,587] Trial 9 finished with value: 0.9845567951821383 and parameters: {'regressor': 'XGBoost', 'max_depth': 6, 'max_features': 5}. Best is trial 8 with value: 0.9852245763533835.
# [I 2022-03-27 21:04:50,964] Trial 10 finished with value: 0.9568202060524347 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 2, 'max_features': 7}. Best is trial 8 with value: 0.9852245763533835.
# [I 2022-03-27 21:04:51,427] Trial 11 finished with value: 0.9837177913038949 and parameters: {'regressor': 'XGBoost', 'max_depth': 4, 'max_features': 4}. Best is trial 8 with value: 0.9852245763533835.
# [I 2022-03-27 21:04:52,097] Trial 12 finished with value: 0.9153488693549434 and parameters: {'regressor': 'RandomForest', 'max_depth': 4, 'max_features': 6}. Best is trial 8 with value: 0.9852245763533835.
# [I 2022-03-27 21:04:52,755] Trial 13 finished with value: 0.9845567951821383 and parameters: {'regressor': 'XGBoost', 'max_depth': 6, 'max_features': 3}. Best is trial 8 with value: 0.9852245763533835.
# [I 2022-03-27 21:04:53,409] Trial 14 finished with value: 0.9861873336374272 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 5, 'max_features': 6}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:04:53,986] Trial 15 finished with value: 0.985691766023269 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 4, 'max_features': 6}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:04:54,448] Trial 16 finished with value: 0.9783683994728235 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 3, 'max_features': 6}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:04:55,103] Trial 17 finished with value: 0.9861873336374272 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 5, 'max_features': 6}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:04:55,835] Trial 18 finished with value: 0.9856357090076635 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 5, 'max_features': 7}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:04:56,488] Trial 19 finished with value: 0.9861873336374272 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 5, 'max_features': 6}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:04:57,032] Trial 20 finished with value: 0.77614653774809 and parameters: {'regressor': 'RandomForest', 'max_depth': 2, 'max_features': 6}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:04:57,689] Trial 21 finished with value: 0.9861873336374272 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 5, 'max_features': 6}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:04:58,411] Trial 22 finished with value: 0.9856357090076635 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 5, 'max_features': 7}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:04:59,105] Trial 23 finished with value: 0.9853949933706203 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 6, 'max_features': 5}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:04:59,769] Trial 24 finished with value: 0.9861873336374272 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 5, 'max_features': 6}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:00,385] Trial 25 finished with value: 0.985430200504429 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 4, 'max_features': 7}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:01,068] Trial 26 finished with value: 0.9853949933706203 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 6, 'max_features': 5}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:01,726] Trial 27 finished with value: 0.9861873336374272 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 5, 'max_features': 6}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:02,471] Trial 28 finished with value: 0.9684653578103969 and parameters: {'regressor': 'RandomForest', 'max_depth': 7, 'max_features': 4}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:02,696] Trial 29 finished with value: 0.9758296442252078 and parameters: {'regressor': 'LightGBM', 'max_depth': 7, 'max_features': 5}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:03,382] Trial 30 finished with value: 0.9153488693549434 and parameters: {'regressor': 'RandomForest', 'max_depth': 4, 'max_features': 6}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:04,061] Trial 31 finished with value: 0.9861873336374272 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 5, 'max_features': 6}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:04,795] Trial 32 finished with value: 0.9856357090076635 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 5, 'max_features': 7}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:05,458] Trial 33 finished with value: 0.9861873336374272 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 5, 'max_features': 6}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:06,326] Trial 34 finished with value: 0.9844596675452194 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 6, 'max_features': 7}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:06,938] Trial 35 finished with value: 0.9851666718949561 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 5, 'max_features': 5}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:07,070] Trial 36 finished with value: 0.9706874365810324 and parameters: {'regressor': 'LightGBM', 'max_depth': 3, 'max_features': 6}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:07,952] Trial 37 finished with value: 0.9844596675452194 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 6, 'max_features': 7}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:08,552] Trial 38 finished with value: 0.9851666718949561 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 5, 'max_features': 5}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:08,700] Trial 39 finished with value: 0.9761140473772666 and parameters: {'regressor': 'LightGBM', 'max_depth': 4, 'max_features': 4}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:09,168] Trial 40 finished with value: 0.9783683994728235 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 3, 'max_features': 6}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:09,828] Trial 41 finished with value: 0.9861873336374272 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 5, 'max_features': 6}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:10,494] Trial 42 finished with value: 0.9861873336374272 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 5, 'max_features': 6}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:11,165] Trial 43 finished with value: 0.9861873336374272 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 5, 'max_features': 6}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:11,835] Trial 44 finished with value: 0.9853949933706203 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 6, 'max_features': 5}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:12,288] Trial 45 finished with value: 0.9837177913038949 and parameters: {'regressor': 'XGBoost', 'max_depth': 4, 'max_features': 2}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:13,026] Trial 46 finished with value: 0.9856357090076635 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 5, 'max_features': 7}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:13,578] Trial 47 finished with value: 0.985691766023269 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 4, 'max_features': 6}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:14,243] Trial 48 finished with value: 0.9845567951821383 and parameters: {'regressor': 'XGBoost', 'max_depth': 6, 'max_features': 5}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:15,138] Trial 49 finished with value: 0.9609405790363023 and parameters: {'regressor': 'RandomForest', 'max_depth': 6, 'max_features': 7}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:15,798] Trial 50 finished with value: 0.9861873336374272 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 5, 'max_features': 6}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:16,470] Trial 51 finished with value: 0.9861873336374272 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 5, 'max_features': 6}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:17,134] Trial 52 finished with value: 0.9861873336374272 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 5, 'max_features': 6}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:17,790] Trial 53 finished with value: 0.9861873336374272 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 5, 'max_features': 6}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:18,350] Trial 54 finished with value: 0.985691766023269 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 4, 'max_features': 6}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:19,003] Trial 55 finished with value: 0.9861873336374272 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 5, 'max_features': 6}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:19,186] Trial 56 finished with value: 0.9765224083258769 and parameters: {'regressor': 'LightGBM', 'max_depth': 5, 'max_features': 7}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:19,854] Trial 57 finished with value: 0.9853949933706203 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 6, 'max_features': 5}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:20,413] Trial 58 finished with value: 0.9842502916631269 and parameters: {'regressor': 'XGBoost', 'max_depth': 5, 'max_features': 6}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:20,912] Trial 59 finished with value: 0.9852245763533835 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 4, 'max_features': 5}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:21,579] Trial 60 finished with value: 0.9861873336374272 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 5, 'max_features': 6}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:22,240] Trial 61 finished with value: 0.9861873336374272 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 5, 'max_features': 6}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:22,901] Trial 62 finished with value: 0.9861873336374272 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 5, 'max_features': 6}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:23,576] Trial 63 finished with value: 0.9861873336374272 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 5, 'max_features': 6}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:24,234] Trial 64 finished with value: 0.9861873336374272 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 5, 'max_features': 6}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:25,099] Trial 65 finished with value: 0.9609405790363023 and parameters: {'regressor': 'RandomForest', 'max_depth': 6, 'max_features': 7}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:25,662] Trial 66 finished with value: 0.985691766023269 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 4, 'max_features': 6}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:26,259] Trial 67 finished with value: 0.9851666718949561 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 5, 'max_features': 5}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:26,630] Trial 68 finished with value: 0.9827996352937972 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 4, 'max_features': 3}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:27,363] Trial 69 finished with value: 0.9856357090076635 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 5, 'max_features': 7}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:28,125] Trial 70 finished with value: 0.9855384347911574 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 6, 'max_features': 6}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:28,786] Trial 71 finished with value: 0.9861873336374272 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 5, 'max_features': 6}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:29,442] Trial 72 finished with value: 0.9861873336374272 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 5, 'max_features': 6}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:30,098] Trial 73 finished with value: 0.9861873336374272 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 5, 'max_features': 6}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:30,753] Trial 74 finished with value: 0.9861873336374272 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 5, 'max_features': 6}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:30,930] Trial 75 finished with value: 0.9765224083258769 and parameters: {'regressor': 'LightGBM', 'max_depth': 5, 'max_features': 5}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:31,601] Trial 76 finished with value: 0.9861873336374272 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 5, 'max_features': 6}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:32,252] Trial 77 finished with value: 0.9861873336374272 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 5, 'max_features': 6}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:33,018] Trial 78 finished with value: 0.9856357090076635 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 5, 'max_features': 7}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:33,473] Trial 79 finished with value: 0.9837177913038949 and parameters: {'regressor': 'XGBoost', 'max_depth': 4, 'max_features': 6}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:34,231] Trial 80 finished with value: 0.9634604096785503 and parameters: {'regressor': 'RandomForest', 'max_depth': 6, 'max_features': 5}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:34,899] Trial 81 finished with value: 0.9861873336374272 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 5, 'max_features': 6}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:35,574] Trial 82 finished with value: 0.9861873336374272 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 5, 'max_features': 6}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:36,239] Trial 83 finished with value: 0.9861873336374272 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 5, 'max_features': 6}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:36,903] Trial 84 finished with value: 0.9861873336374272 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 5, 'max_features': 6}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:37,562] Trial 85 finished with value: 0.9861873336374272 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 5, 'max_features': 6}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:38,220] Trial 86 finished with value: 0.9861873336374272 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 5, 'max_features': 6}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:38,605] Trial 87 finished with value: 0.9568202060524347 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 2, 'max_features': 7}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:39,264] Trial 88 finished with value: 0.9861873336374272 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 5, 'max_features': 6}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:39,413] Trial 89 finished with value: 0.9761140473772666 and parameters: {'regressor': 'LightGBM', 'max_depth': 4, 'max_features': 6}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:40,102] Trial 90 finished with value: 0.9853949933706203 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 6, 'max_features': 5}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:40,762] Trial 91 finished with value: 0.9861873336374272 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 5, 'max_features': 6}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:41,429] Trial 92 finished with value: 0.9861873336374272 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 5, 'max_features': 6}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:42,097] Trial 93 finished with value: 0.9861873336374272 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 5, 'max_features': 6}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:42,764] Trial 94 finished with value: 0.9861873336374272 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 5, 'max_features': 6}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:43,420] Trial 95 finished with value: 0.9861873336374272 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 5, 'max_features': 6}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:44,094] Trial 96 finished with value: 0.9861873336374272 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 5, 'max_features': 6}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:44,744] Trial 97 finished with value: 0.9861873336374272 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 5, 'max_features': 6}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:45,400] Trial 98 finished with value: 0.9861873336374272 and parameters: {'regressor': 'GradientBoosting', 'max_depth': 5, 'max_features': 6}. Best is trial 14 with value: 0.9861873336374272.
# [I 2022-03-27 21:05:45,967] Trial 99 finished with value: 0.9842502916631269 and parameters: {'regressor': 'XGBoost', 'max_depth': 5, 'max_features': 7}. Best is trial 14 with value: 0.9861873336374272.
# FrozenTrial(number=14, values=[0.9861873336374272], datetime_start=datetime.datetime(2022, 3, 27, 21, 4, 52, 759555), datetime_complete=datetime.datetime(2022, 3, 27, 21, 4, 53, 409630), params={'regressor': 'GradientBoosting', 'max_depth': 5, 'max_features': 6}, distributions={'regressor': CategoricalDistribution(choices=('GradientBoosting', 'XGBoost', 'LightGBM', 'RandomForest')), 'max_depth': IntUniformDistribution(high=7, low=2, step=1), 'max_features': IntUniformDistribution(high=7, low=2, step=1)}, user_attrs={}, system_attrs={}, intermediate_values={}, trial_id=14, state=TrialState.COMPLETE, value=None)

# %%
print(study.best_params)
# Out:
# {'regressor': 'GradientBoosting', 'max_depth': 5, 'max_features': 6}

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=17)
from sklearn.ensemble import GradientBoostingRegressor
from time import time

gbr = GradientBoostingRegressor(random_state=17,max_depth= 5,max_features= 6)
gbr.fit(X_train,y_train)
print('Test Data')
y_pred2 = gbr.predict(X_test)
evalmetric(y_test,y_pred2)
# Out:
# Test Data
# MSE: 1542353.8550284477
# RMSE: 1241.915397693598
# MAE: 659.2526559755419
# MAPE: 5.307389159446252
# R-Squared: 0.985108420764872

# %% [markdown]
# R^2 value is 0.985108420764872
